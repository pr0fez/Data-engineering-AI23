# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

movie_id='0114885'
url = f'https://www.imdb.com/title/tt{movie_id}/reviews'

resp = requests.get(url)
soup = BeautifulSoup(resp.content, 'html.parser')

# %%
df = pd.DataFrame([r.get_text() for r in soup.find_all(attrs={'class':'text show-more__control'})])
df
# Out:
#                                                     0
# 0   I got an opportunity to see Waiting To Exhale ...
# 1   I have the video of this movie and it grew on ...
# 2   If you've read the book, you can fill in the s...
# 3   I read some of the other comments comcerning t...
# 4   Whitney houston...no longer with us. Angela ba...
# 5   WAITING TO EXHALE Waiting, and waiting, and wa...
# 6   This wasn't a bad movie. The acting was great ...
# 7   It had some laughs, but overall the motivation...
# 8   This was a good movie, even though I'm not the...
# 9   I was actually an extra in this movie and had ...
# 10  So I finally got around to watching "Waiting t...
# 11  While this movie truly is bound to be more app...
# 12  this movie and its story are quite good on the...
# 13  This movie is awful! The caracters are shallow...
# 14  That's the word I'd use to describe the film, ...
# 15  Directed by Forest Whitaker and adapted from a...
# ...

# %%
movie_id='862'
url = f'https://www.themoviedb.org/movie/{movie_id}/reviews?language=en-US'

resp = requests.get(url)
soup = BeautifulSoup(resp.content, 'html.parser')

# %%
soup
# Out:
# <!DOCTYPE html>
#
# <html class="no-js" lang="se">
# <head>
# <title>Toy Story - Reviews — The Movie Database (TMDB)</title>
# <meta content="on" http-equiv="cleartype"/>
# <meta charset="utf-8"/>
# <meta content="Movies, TV Shows, Streaming, Reviews, API, Actors, Actresses, Photos, User Ratings, Synopsis, Trailers, Teasers, Credits, Cast" name="keywords"/>
# <meta content="yes" name="mobile-web-app-capable"/>
# <meta content="yes" name="apple-mobile-web-app-capable"/>
# <meta content="width=device-width,initial-scale=1" name="viewport"/>
# <meta content="Led by Woody, Andy's toys live happily in his room until Andy's birthday brings Buzz Lightyear onto the scene. Afraid of losing his place in Andy's heart, Woody plots against Buzz. But when circumstances separate Buzz and Woody from their owner, the duo eventually learns to put aside their differences." name="description"/>
# ...

# %%
info = soup.find_all(attrs={'class': 'info'})
reviews = list()
for i in info:
    a = i.find('a')
    ref = a.attrs['href']
    url = 'https://www.themoviedb.org' + ref
    resp = requests.get(url)
    s = BeautifulSoup(resp.content, 'html.parser')
    review = s.find(attrs={'class': 'content column pad'})
    reviews += [review.get_text()]
reviews
# Out:
# ["\nToy Story (1995)\nWritten by Gimly on July 16, 2019\nThis movie came out when I was three. Now I'm twenty seven and the goddamn thing still holds up.\nFinal rating:★★★★ - Very strong appeal. A personal favourite.\n",
#  '\nToy Story (1995)\nWritten by JPV852 on October 14, 2019\nDecided to revisit this after many years and still holds up so well. Great movie for both kids and adults with wonderful teachable moments. Just a groundbreaking animated movie all around. 4.5/5\n',
# ...
